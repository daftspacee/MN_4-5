# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from keras.layers import Dropout

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

print("x_train original shape", x_train.shape)
print("y_train original shape", y_train.shape)


classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(100,150):
    plt.subplot(5,10,i-100+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(classes[y_train[i][0]])
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# x_train original shape (50000, 32, 32, 3)
# y_train original shape (50000, 1)

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
    model = keras.Sequential([
        layers.Flatten(input_shape=(32, 32, 3)),
        layers.Dense(128, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])

    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

    model.summary()

    history = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_split=0.2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 128)               393344
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 404010 (1.54 MB)
# Trainable params: 404010 (1.54 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 625/625 [==============================] - 9s 13ms/step - loss: 1.9400 - accuracy: 0.2965 - val_loss: 1.8435 - val_accuracy: 0.3364
# Epoch 2/20
# 625/625 [==============================] - 6s 9ms/step - loss: 1.7689 - accuracy: 0.3629 - val_loss: 1.7731 - val_accuracy: 0.3637
# Epoch 3/20
# 625/625 [==============================] - 8s 13ms/step - loss: 1.6869 - accuracy: 0.3980 - val_loss: 1.6920 - val_accuracy: 0.4003
# Epoch 4/20
# 625/625 [==============================] - 6s 10ms/step - loss: 1.6408 - accuracy: 0.4123 - val_loss: 1.6639 - val_accuracy: 0.4100
# Epoch 5/20
# 625/625 [==============================] - 7s 11ms/step - loss: 1.6033 - accuracy: 0.4284 - val_loss: 1.6607 - val_accuracy: 0.4063
# Epoch 6/20
# 625/625 [==============================] - 8s 13ms/step - loss: 1.5686 - accuracy: 0.4420 - val_loss: 1.5877 - val_accuracy: 0.4310
# Epoch 7/20
# 625/625 [==============================] - 7s 12ms/step - loss: 1.5421 - accuracy: 0.4462 - val_loss: 1.5595 - val_accuracy: 0.4409
# Epoch 8/20
# 625/625 [==============================] - 6s 10ms/step - loss: 1.5249 - accuracy: 0.4538 - val_loss: 1.5832 - val_accuracy: 0.4344
# Epoch 9/20
# 625/625 [==============================] - 7s 11ms/step - loss: 1.5078 - accuracy: 0.4602 - val_loss: 1.6071 - val_accuracy: 0.4272
# Epoch 10/20
# 625/625 [==============================] - 8s 12ms/step - loss: 1.4985 - accuracy: 0.4633 - val_loss: 1.5743 - val_accuracy: 0.4382
# Epoch 11/20
# 625/625 [==============================] - 7s 12ms/step - loss: 1.4872 - accuracy: 0.4695 - val_loss: 1.5696 - val_accuracy: 0.4412
# Epoch 12/20
# 625/625 [==============================] - 6s 10ms/step - loss: 1.4668 - accuracy: 0.4742 - val_loss: 1.5374 - val_accuracy: 0.4525
# Epoch 13/20
# 625/625 [==============================] - 7s 11ms/step - loss: 1.4546 - accuracy: 0.4785 - val_loss: 1.5503 - val_accuracy: 0.4515
# Epoch 14/20
# 625/625 [==============================] - 7s 11ms/step - loss: 1.4472 - accuracy: 0.4825 - val_loss: 1.5129 - val_accuracy: 0.4645
# Epoch 15/20
# 625/625 [==============================] - 7s 11ms/step - loss: 1.4310 - accuracy: 0.4867 - val_loss: 1.5222 - val_accuracy: 0.4588
# Epoch 16/20
# 625/625 [==============================] - 7s 11ms/step - loss: 1.4316 - accuracy: 0.4879 - val_loss: 1.5099 - val_accuracy: 0.4633
# Epoch 17/20
# 625/625 [==============================] - 6s 10ms/step - loss: 1.4213 - accuracy: 0.4906 - val_loss: 1.5145 - val_accuracy: 0.4675
# Epoch 18/20
# 625/625 [==============================] - 8s 12ms/step - loss: 1.4104 - accuracy: 0.4943 - val_loss: 1.5419 - val_accuracy: 0.4580
# Epoch 19/20
# 625/625 [==============================] - 9s 14ms/step - loss: 1.3992 - accuracy: 0.4988 - val_loss: 1.5134 - val_accuracy: 0.4669
# Epoch 20/20
# 625/625 [==============================] - 7s 11ms/step - loss: 1.3949 - accuracy: 0.5027 - val_loss: 1.5382 - val_accuracy: 0.4578

# %%
# Виведення графіків функції втрат та точності
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title("Графік функції втрат")
plt.legend()
plt.grid()
plt.show()

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title("Графік точності")
plt.grid()
plt.legend()
plt.show()

# %%
# Оцінка точності на тестовому наборі
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_accuracy*100:.2f}%")

# Розпізнавання 10 випадкових зображень
random_indices = np.random.choice(x_test.shape[0], 10, replace=False)
random_images = x_test[random_indices]
predictions = model.predict(random_images)

# Виведення результатів розпізнавання
for i in range(10):
    predicted_class = np.argmax(predictions[i])
    true_class = np.argmax(y_test[random_indices[i]])
    print(f"Image {i + 1}: Predicted Class {predicted_class}, True Class {true_class}")

# Виведення зображень для перевірки
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(random_images[i], cmap='gray')
    plt.title(f"True: {true_class}, Predicted: {predicted_class}")
    plt.axis('off')
plt.show()
# Out:
# 313/313 - 2s - loss: 1.5070 - accuracy: 0.4689 - 2s/epoch - 6ms/step
#
# Test Accuracy: 46.89%
# 1/1 [==============================] - 0s 112ms/step
# Image 1: Predicted Class 6, True Class 6
# Image 2: Predicted Class 0, True Class 0
# Image 3: Predicted Class 0, True Class 9
# Image 4: Predicted Class 2, True Class 2
# Image 5: Predicted Class 0, True Class 0
# Image 6: Predicted Class 6, True Class 4
# Image 7: Predicted Class 7, True Class 7
# Image 8: Predicted Class 3, True Class 6
# Image 9: Predicted Class 6, True Class 6
# Image 10: Predicted Class 0, True Class 1

# %%
# Виведення статистики моделі
print("\nModel Evaluation:")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy*100:.2f}%")

# Статистика параметрів моделі
total_parameters = sum([np.prod(layer.get_weights()[i].shape) for layer in model.layers for i in range(len(layer.get_weights()))])

print(f"\nTotal Parameters: {total_parameters}")

# Статистика шарів моделі
for i, layer in enumerate(model.layers):
    print(f"\nLayer {i + 1}: {layer.name}")
    print(f"Number of Parameters: {layer.count_params()}")
    print(f"Input Shape: {layer.input_shape}, Output Shape: {layer.output_shape}")
# Out:
# Model Evaluation:
# Test Loss: 1.5070
# Test Accuracy: 46.89%
#
# Total Parameters: 404010
#
# Layer 1: flatten
# Number of Parameters: 0
# Input Shape: (None, 32, 32, 3), Output Shape: (None, 3072)
#
# Layer 2: dense
# Number of Parameters: 393344
# Input Shape: (None, 3072), Output Shape: (None, 128)
#
# Layer 3: dense_1
# Number of Parameters: 8256
# Input Shape: (None, 128), Output Shape: (None, 64)
#
# Layer 4: dense_2
# Number of Parameters: 2080
# Input Shape: (None, 64), Output Shape: (None, 32)
#
# Layer 5: dense_3
# Number of Parameters: 330
# Input Shape: (None, 32), Output Shape: (None, 10)

# %% [markdown]
# #**Висновки:** під час практичної роботи була розроблена модель з чотирма Dense-шарами. Я аналізував графіки функції втрат та точності під час процесу тренування моделі. Також я візуалізував 10 випадкових зображень з тестового набору, щоб оцінити результати моделі. Отримана точність на тестових даних склала 49.15%. Важливо відзначити, що розроблена модель не використовує згорткові шари при побудові, що може впливати на її результати та точність прогнозування.
